# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df = pd.read_csv("adult_eda.csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# there are NaN values at features (education-num, retionship)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check the sum of Missing Values per column
df.isnull().sum()
# there are NaN values at features (education-num, retionship)
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values
df.isnull().sum()/len(df)*100
# there are NaN values at features (education-num, retionship) an the percentages are shown below.
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education-num     2.463
# marital-status    0.000
# occupation        0.000
# relationship     15.565
# race              0.000
# sex               0.000
# capital-gain      0.000
# capital-loss      0.000
# hours-per-week    0.000
# native-country    0.000
# salary            0.000
# dtype: float64

# %%
# Check if the Dataset have any Duplicate

df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
df[df.duplicated()].index
# Out:
# Int64Index([ 4881,  5104,  9171, 11631, 13084, 15059, 17040, 18555, 18698,
#             21318, 21490, 21875, 22300, 22367, 22494, 25872, 26313, 28230,
#             28522, 28846, 29157, 30845, 31993, 32404],
#            dtype='int64')

# %%
# dropped dublicates
df = df.drop_duplicates()

# %%
# checked if any dublicated values. There is no dublicated values
df[df.duplicated()].index
# Out:
# Int64Index([], dtype='int64')

# %%
# Check the shape of the Dataset
df.shape
# Out:
# (32537, 15)

# %%
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
# the columns names is not approprite, so we will chanege the names of the columns
df.rename(columns={"education-num":"education_num", "marital-status":"marital_status", "capital-gain":"capital_gain",
                   "capital-loss":"capital_loss", "hours-per-week":"hours_per_week", "native-country":"native_country"},
          inplace=True)

# %%
# checked it they are changed
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
# to see the names of columns
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# to see the description of only object dtype columns
df.describe(include=object).T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
# the names of only object dtype columns
# Assign the Columns (Features) of object data type as "object_col"
object_col = df.describe(include=object).columns
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
# value counts of columns that have object datatype
for i in object_col:
    print(i)
    print("--"*8)
    print(df[i].value_counts(dropna=False))
    print("##"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ########################################
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ########################################
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %%
df.workclass.value_counts()
# there are 1876 unknown values with "?"
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.education.value_counts()
# haw can we join the categories. For example three categories,low level, medium level, high level.
# Elementary and secondary school is similar across the US. However, there are minor variations from state to state. Elementary and secondary education is divided into:
# Elementary School: Runs for 6-7 years starting in Kindergarten through to Grade 5 or 6
# Middle School: Runs for 2-3 years starting in Grade 6 or 7 through to Grade 8
# High School: Runs for 4 years starting in Grade 9 through to Grade 12
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df["marital_status"].value_counts()
# we can join divorced, widowed and separated
# we can make two categories as married and unmarried
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df["occupation"].value_counts()
# there are 1843 unknown values with "?"
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df[["relationship"]].value_counts(dropna=False)
# we can join not-in-family and unmarried togather
# 5068 NaN values
# Out:
# relationship
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# dtype: int64

# %%
df["race"].value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df["sex"].value_counts()
# males are nearly two times more than females
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
df["native_country"].value_counts()
# we may have two categories as US and other countries.
# there are 583 unknown values with "?"
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# Check if the Dataset has any Question Mark "?"
df[df == "?"].any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## First---Salary (Target Feature)

# %% [markdown]
# # Check the count of person in each "salary" levels and visualize it with a countplot

# %%
df["salary"].value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# fig, ax = plt.subplots()
ax = sns.countplot(x="salary", data=df)
plt.bar_label(ax.containers[0]);

# %% [markdown]
# # Check the percentage of person in each "salary" levels and visualize it with a pieplot

# %%
df["salary"].value_counts()/len(df)*100
# Out:
# <=50K   75.907
# >50K    24.093
# Name: salary, dtype: float64

# %%
explode = [0, 0.1]
palette_color = sns.color_palette('pastel')
#  Name of a seaborn palette (deep, muted, bright, pastel, dark, colorblind)
ax = plt.pie(df["salary"].value_counts(), 
        labels = df["salary"].value_counts().index, 
        autopct='%.1f%%', 
        explode=explode,
        colors= palette_color)

plt.show()

# %% [markdown]
# nearly 3 quartes of people gains more than 50K

# %% [markdown]
# ## A-Numeric Values

# %% [markdown]
# ## 1-Age

# %% [markdown]
# # Check the boxplot to see extreme values

# %%
sns.boxplot(df.age);

# %% [markdown]
# ### Check the histplot/kdeplot to see distribution of feature

# %%
sns.histplot(x="age", data=df, kde=True, bins=20)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# Check the statistical values
df["age"].describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels
sns.boxplot(x="salary", y="age", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
sns.histplot(x= "age", hue="salary", data=df, bins=20, kde=True);

# %%
sns.kdeplot(x= "age", hue="salary", data=df, shade=0.5);

# %%
# Check the statistical values by "salary" levels
df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %%
# the disribution of high level salary is normal distribition but low level salary has right skewed distribution.

# %% [markdown]
# ## 2- fnlwgt

# %% [markdown]
# ### Check the boxplot to see extreme values

# %%
sns.boxplot(x="fnlwgt", data=df);

# %%
# Check the histplot/kdeplot to see distribution of feature
sns.histplot(x="fnlwgt", data=df, kde=True);

# %%
sns.kdeplot(x="fnlwgt", data=df, shade=True);

# %%
# Check the statistical values
df["fnlwgt"].describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels
sns.boxplot(x="salary", y="fnlwgt", data=df);
# fnlwgt is totally insensitive to salary

# %%
sns.kdeplot(x="fnlwgt", hue="salary", data=df, shade=True)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %%
# Check the statistical values by "salary" levels
df.groupby("salary")["fnlwgt"].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# # 3-capital_gain

# %%
# Check the boxplot to see extreme values
sns.boxplot(x="capital_gain", data=df);

# %%
# Check the histplot/kdeplot to see distribution of feature
sns.histplot(x="capital_gain", data=df, kde=True);

# %%
sns.kdeplot(x="capital_gain", data=df, shade=True);

# %%
df["capital_gain"].describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels
sns.boxplot(x="salary", y="capital_gain", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_gain'>

# %%
sns.histplot(x="capital_gain", hue="salary", data=df)
# Out:
# <AxesSubplot:xlabel='capital_gain', ylabel='Count'>

# %%
sns.kdeplot(x="capital_gain", hue="salary", data=df)
# Out:
# <AxesSubplot:xlabel='capital_gain', ylabel='Density'>

# %%
# Check the statistical values by "salary" levels
df.groupby("salary")["capital_gain"].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %%
# Check the statistical values by "salary" levels for capital_gain not equal the zero
df[df["capital_gain"] != 0].groupby("salary")["capital_gain"].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# ## 4-capital_loss

# %%
# Check the boxplot to see extreme values
sns.boxplot(x="capital_loss", data=df);

# %%
# Check the histplot/kdeplot to see distribution of feature
sns.histplot(x="capital_loss", data=df);

# %%
sns.kdeplot(x="capital_loss", data=df, shade=True);

# %%
# Check the statistical values
df["capital_loss"].describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels
sns.boxplot(x="salary", y="capital_loss", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_loss'>

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels
sns.kdeplot(x="capital_loss", hue="salary", shade=True, data=df);

# %%
# Check the statistical values by "salary" levels
df.groupby("salary")["capital_loss"].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %%
# Check the statistical values by "salary" levels for capital_loss not equel the zero
df[df["capital_loss"] != 0].groupby("salary")["capital_loss"].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# ## 5-hours_per_week

# %%
# Check the boxplot to see extreme values
sns.boxplot(x="hours_per_week", data=df);

# %%
# Check the histplot/kdeplot to see distribution of feature
sns.kdeplot(x="hours_per_week", data=df, shade=True);

# %%
# Check the statistical values
df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %%
# Check the boxplot and histplot/kdeplot by "salary" levels
sns.boxplot(x="salary", y="hours_per_week", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='hours_per_week'>

# %%
sns.kdeplot(x="hours_per_week", hue="salary", data=df, shade=True);

# %%
# Check the statistical values by "salary" levels
df.groupby("salary").hours_per_week.describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %%
# See the relationship between each numeric features by target feature (salary) in one plot basically
sns.pairplot(df, hue= "salary" ,palette="twilight_r",corner=True)

# %%
# g=sns.PairGrid(df, hue= "salary", palette="viridis")

# g=g.map_upper(sns.scatterplot, linewidth=1, edgecolor="w", s=100)
# g=g.map_diag(sns.histplot)
# g=g.map_lower(sns.kdeplot)
# g=g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ELITEB~1\AppData\Local\Temp/ipykernel_19004/1569590155.py in <module>
#       3 g=g.map_upper(sns.scatterplot, linewidth=1, edgecolor="w", s=100)
#       4 g=g.map_diag(sns.histplot)
# ----> 5 g=g.map_lower(sns.kdeplot)
#       6 g=g.add_legend()
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_lower(self, func, **kwargs)
#    1355         """
#    1356         indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1357         self._map_bivariate(func, indices, **kwargs)
#    1358         return self
#    1359
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1537             if ax is None:  # i.e. we are in corner mode
#    1538                 continue
# -> 1539             self._plot_bivariate(x_var, y_var, ax, func, **kws)
# ...

# %% [markdown]
# # B - Categorical Features

# %% [markdown]
# ## 1-education & education_num

# %%
# Detect the similarities between these features by comparing unique values
df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df.education_num.value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.groupby(["education", "education_num"], dropna=False)["education"].count()
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %%
# Visualize the count of person in each categories for these features (education, education_num) separately
sns.countplot(x="education", data=df)
plt.xticks(rotation=90);

# %%
sns.countplot(x="education_num", data=df);
# plt.xticks(rotation=90);

# %%
# Check the count of person in each "salary" levels by these features (education and education_num) 
# separately and visualize them with countplot
df.groupby("education")["salary"].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
sns.countplot(x="education", hue="salary", data=df)
plt.xticks(rotation=90);

# %%
df.groupby("education_num")["salary"].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
sns.countplot(x="education_num", hue="salary", data=df)
# plt.xticks(rotation=90);
# Out:
# <AxesSubplot:xlabel='education_num', ylabel='count'>

# %%
# Visualize the boxplot of "education_num" feature by "salary" levels
sns.boxplot(x="salary", y="education_num", data=df);

# %%
# Decrease the number of categories in "education" feature as low, medium, and high level 
# and create a new feature with this new categorical data.
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"
df["education_summary"] = df.education.apply(mapping_education)
df.education_summary.value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education_summary, dtype: int64

# %%
# Visualize the count of person in each categories for these new education levels (high, medium, low)
sns.countplot(x="education_summary", data=df)
# Out:
# <AxesSubplot:xlabel='education_summary', ylabel='count'>

# %%
# Check the count of person in each "salary" levels by these new education levels(high, medium, low) 
# and visualize it with countplot
df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
sns.countplot(x="education_summary", hue="salary", data=df)
# Out:
# <AxesSubplot:xlabel='education_summary', ylabel='count'>

# %%
# Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) 
# and visualize it with pie plot separately
df.groupby("education_summary")["salary"].value_counts(normalize=True)
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
df_perc = pd.DataFrame(df.groupby("education_summary")["salary"].value_counts(normalize=True))
df_perc.columns = ["Percentages"]
df_perc = df_perc.unstack(level=0)
df_perc
# Out:
#                        Percentages
# education_summary high_level_grade low_level_grade medium_level_grade
# salary
# <=50K                        0.515           0.943              0.818
# >50K                         0.485           0.057              0.182

# %%
fig, ax=plt.subplots(1,3, figsize=(20,9))
colors = ["#ffb3b3", "#99ceff"]
ax[0].pie(x=df_perc.Percentages.high_level_grade, labels=df.salary.value_counts().index, colors=colors, autopct="%.2f%%" )
ax[0].set_title("high_level_grade")

ax[1].pie(x=df_perc.Percentages.low_level_grade, labels=df.salary.value_counts().index,colors=colors, autopct="%.2f%%");
ax[1].set_title("low_level_grade")

ax[2].pie(x=df_perc.Percentages.medium_level_grade, labels=df.salary.value_counts().index, colors=colors, autopct="%.2f%%");
ax[2].set_title("medium_level_grade")
plt.show()

# %%
# Check the count of person in each these new education levels(high, medium, low) by "salary" levels 
# and visualize it with countplot
df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
sns.countplot(x="salary", hue="education_summary", data=df);

# %%
# Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels 
# and visualize it with pie plot separately
df.groupby("salary")["education_summary"].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
df_perc1 = pd.DataFrame(df.groupby("salary")["education_summary"].value_counts(normalize=True))
df_perc1.columns = ["Percentages"]
df_perc1 = df_perc1.unstack(level=0)
df_perc1
# Out:
#                    Percentages
# salary                   <=50K  >50K
# education_summary
# high_level_grade         0.168 0.499
# low_level_grade          0.162 0.031
# medium_level_grade       0.670 0.470

# %%
fig, ax=plt.subplots(1,2, figsize=(20,9))
colors = ["#ffb3b3", "#99ceff", "#88eeff", "#77ccff"]
ax[0].pie(x=df_perc1.Percentages["<=50K"], labels=df.education_summary.value_counts().index, startangle=240, colors=colors, autopct="%.2f%%" )
ax[0].set_title("<=50K")

ax[1].pie(x=df_perc1.Percentages[">50K"], labels=df.education_summary.value_counts().index, startangle=180, colors=colors, autopct="%.2f%%");
ax[1].set_title(">50K")
# Out:
# Text(0.5, 1.0, '>50K')

# %%
df_perc
# Out:
#                        Percentages
# education_summary high_level_grade low_level_grade medium_level_grade
# salary
# <=50K                        0.515           0.943              0.818
# >50K                         0.485           0.057              0.182

# %%
df_perc1
# Out:
#                    Percentages
# salary                   <=50K  >50K
# education_summary
# high_level_grade         0.168 0.499
# low_level_grade          0.162 0.031
# medium_level_grade       0.670 0.470

# %%
new = df.groupby("salary")["education_summary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new
# Out:
#   salary   education_summary  percentage
# 0  <=50K  medium_level_grade       0.670
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 3   >50K    high_level_grade       0.499
# 4   >50K  medium_level_grade       0.470
# 5   >50K     low_level_grade       0.031

# %%
df_perc2 = pd.DataFrame(df.groupby("salary")["education_summary"].value_counts(normalize=True))
df_perc2.columns = ["Percentages"]
df_perc2 = df_perc2.unstack(level=0)
df_perc2
# Out:
#                    Percentages
# salary                   <=50K  >50K
# education_summary
# high_level_grade         0.168 0.499
# low_level_grade          0.162 0.031
# medium_level_grade       0.670 0.470

# %%
fig, ax=plt.subplots(1,2, figsize=(20,9))
colors = ["#98e698", "#ffb3b3", "#99ceff"]
ax[0].pie(x=df_perc2.Percentages["<=50K"], labels=df.education_summary.value_counts().index, startangle=240, colors=colors, autopct="%.2f%%" )
ax[0].set_title("<=50K")

ax[1].pie(x=df_perc2.Percentages[">50K"], labels=df.education_summary.value_counts().index, startangle=180, colors=colors, autopct="%.2f%%");
ax[1].set_title(">50K")
# Out:
# Text(0.5, 1.0, '>50K')

# %%
# Your Code is Here
percentages_1 = new[new.salary == "<=50K"]["percentage"]*100
percentages_2 = new[new.salary == ">50K"]["percentage"]*100
colors_2 = ["#98e698", "#ffb3b3", "#99ceff" ]
colors_3 = ["#ffb3b3", "#98e698", "#99ceff" ]
fig, ax = plt.subplots(1,2)
ax[0].pie(x=percentages_1, labels=["medium", "high", "low"], colors=colors_2, autopct="%.2f%%", startangle=120)
ax[0].set_title("<=50K")
ax[0].set_ylabel("percentage")

ax[1].pie(x=percentages_2, labels=["high", "medium", "low"], colors=colors_3, autopct="%.2f%%", startangle=0)
ax[1].set_title(">50K")
ax[1].set_ylabel("percentage")
plt.show()

# %% [markdown]
# # 2-Marital_status & relationship

# %% [markdown]
# ## Detect the similarities between these features by comparing unique values

# %%
df.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df.relationship.value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"
df.groupby("relationship")["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
# ...

# %%
ax = sns.countplot(x="marital_status", data=df);
ax.tick_params(rotation=45, axis="x")

# %% [markdown]
# ## Check the count of person in each "salary" levels by categories and visualize it with countplot

# %%
df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
ax = sns.countplot(x="marital_status", hue="salary", data=df);
ax.tick_params(rotation=45, axis="x")

# %% [markdown]
# ### Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"
df["marital_status_summary"] = df["marital_status"].apply(mapping_marital_status)
df["marital_status_summary"].value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status_summary, dtype: int64

# %% [markdown]
# ### Visualize the count of person in each categories for these new marital status (married, unmarried)

# %%
sns.countplot(x="marital_status_summary", data=df);

# %% [markdown]
# ## Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot

# %%
df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
sns.countplot(x="marital_status_summary", hue="salary", data=df);

# %%
# Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately
df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
new_2 = df.groupby(["marital_status_summary"])["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
new_2
# Out:
#   marital_status_summary salary  percentage
# 0                married  <=50K       0.563
# 1                married   >50K       0.437
# 2              unmarried  <=50K       0.935
# 3              unmarried   >50K       0.065

# %%
new_2[new_2.marital_status_summary == "married"]["percentage"]
# Out:
# 0   0.563
# 1   0.437
# Name: percentage, dtype: float64

# %%
percentages_3 = new_2[new_2.marital_status_summary == "married"]["percentage"]
percentages_4 = new_2[new_2.marital_status_summary == "unmarried"]["percentage"]
fig, ax = plt.subplots(1,2)
ax[0].pie(x=percentages_3, labels=new_2.salary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[0].set_title("married")
ax[0].set_ylabel("salary")

ax[1].pie(x=percentages_4, labels=new_2.salary.value_counts().index, autopct="%.2f%%", colors=colors)
ax[1].set_title("unmarried")
ax[1].set_ylabel("salary")
# Out:
# Text(0, 0.5, 'salary')

# %%
fig = plt.figure(figsize=(15,8),dpi=98)
ax = fig.add_subplot(121)
cts = df.groupby("marital_status_summary").salary.value_counts().married
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%")
ax.set_title("married");
ax = fig.add_subplot(122)
cts = df.groupby("marital_status_summary").salary.value_counts().unmarried
ax.pie(cts,labels=cts.index,
      autopct="%.1f%%")
ax.set_title("unmarried");

# %% [markdown]
# ## Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot

# %%
df.groupby("salary")["marital_status_summary"].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(x="salary", hue="marital_status_summary", data=df);

# %% [markdown]
# ## Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately

# %%
df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
mar_sta_frame = df.groupby("salary")["marital_status_summary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
mar_sta_frame
# Out:
#   salary marital_status_summary  percentage
# 0  <=50K              unmarried       0.649
# 1  <=50K                married       0.351
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
fig = plt.figure(figsize=(15,8),dpi=98)
ax = fig.add_subplot(121)
cts = df.groupby("salary").marital_status_summary.value_counts()["<=50K"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%")
ax.set_title("<=50K");
ax = fig.add_subplot(122)
cts = df.groupby("salary").marital_status_summary.value_counts()[">50K"]
ax.pie(cts,labels=cts.index,
      autopct="%.1f%%")
ax.set_title(">50K");

# %% [markdown]
# # 3-workclass

# %%
# Check the count of person in each categories and visualize it with countplot
df.workclass.value_counts(dropna=True)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
ax = sns.countplot(x="workclass", data=df);
ax.tick_params(rotation=45, axis="x")

# %%
# Replace the value "?" to the value "Unknown"
df.workclass.replace(to_replace="?", value="Unknown", inplace=True)
df.workclass.value_counts(dropna=True)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Check the count of person in each "salary" levels by workclass groups and visualize it with countplot
ax = sns.countplot(x="workclass", hue="salary", data=df)
ax.tick_params(rotation=90, axis="x")

# %%
# Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot
df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
df_frame = df.groupby("workclass")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_frame
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
sns.barplot(x="workclass", y="percentage", data=df_frame, hue="salary");

# %%
# Check the count of person in each workclass groups by "salary" levels and visualize it with countplot
df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
ax = sns.countplot(x="salary", hue="workclass", data=df)
ax.tick_params(rotation=90, axis="x")

# %%
# Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot
df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
df_frame = df.groupby("salary")["workclass"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_frame
# Out:
#    salary         workclass  percentage
# 0   <=50K           Private       0.717
# 1   <=50K  Self-emp-not-inc       0.074
# 2   <=50K           Unknown       0.067
# 3   <=50K         Local-gov       0.060
# 4   <=50K         State-gov       0.038
# 5   <=50K       Federal-gov       0.024
# 6   <=50K      Self-emp-inc       0.020
# 7   <=50K       Without-pay       0.001
# 8   <=50K      Never-worked       0.000
# 9    >50K           Private       0.633
# 10   >50K  Self-emp-not-inc       0.092
# 11   >50K      Self-emp-inc       0.079
# 12   >50K         Local-gov       0.079
# 13   >50K       Federal-gov       0.047
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
ax = sns.barplot(x="salary", y="percentage", data=df_frame, hue="workclass");

# ax.annotate(ax, (0.1,0.1))

# %% [markdown]
# # 4-occupation

# %%
# Check the count of person in each categories and visualize it with countplot
df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
ax = sns.countplot(x="occupation", data=df);
ax.tick_params(rotation=90, axis="x")

# %%
# Replace the value "?" to the value "Unknown"
df.occupation.replace(to_replace="?", value="Unknown", inplace=True)
df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Check the count of person in each "salary" levels by occupation groups and visualize it with countplot
df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
ax = sns.countplot(x="occupation", data=df, hue="salary");
ax.tick_params(rotation=90, axis="x")

# %%
# Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot
df.groupby("occupation")["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
df_frame = df.groupby("occupation")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_frame
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
ax = sns.barplot(x="occupation", y="percentage", data=df_frame, hue="salary");
ax.tick_params(rotation=90, axis="x")

# %%
# Check the count of person in each occupation groups by "salary" levels and visualize it with countplot
df.groupby("salary")["occupation"].value_counts(dropna=False)
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
ax = sns.countplot(x="salary", data=df, hue="occupation");
ax.tick_params(rotation=90, axis="x")

# %%
# Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot
df.groupby("salary")["occupation"].value_counts(dropna=False, normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
df_frame = df.groupby("salary")["occupation"].value_counts(dropna=False, normalize=True).to_frame(name="percentage").reset_index()
df_frame
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            Unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# ...

# %%
ax = sns.barplot(x="salary", y="percentage", data=df_frame, hue="occupation");
ax.tick_params(rotation=90, axis="x")

# %% [markdown]
# # 5-race

# %%
# Check the count of person in each categories and visualize it with countplot
df.race.value_counts(dropna=False)
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
ax = sns.countplot(x="race", data=df);
ax.tick_params(rotation=45, axis="x")

# %%
# Check the count of person in each "salary" levels by races and visualize it with countplot
df.groupby("race")["salary"].value_counts(dropna=False)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
ax = sns.countplot(x="race", data=df, hue="salary");
ax.tick_params(rotation=45, axis="x")

# %%
# Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot
df.groupby("race")["salary"].value_counts(dropna=False, normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
df_frame = df.groupby("race")["salary"].value_counts(dropna=False, normalize=True).to_frame(name="percentage").reset_index()
df_frame
# Out:
#                  race salary  percentage
# 0  Amer-Indian-Eskimo  <=50K       0.884
# 1  Amer-Indian-Eskimo   >50K       0.116
# 2  Asian-Pac-Islander  <=50K       0.734
# 3  Asian-Pac-Islander   >50K       0.266
# 4               Black  <=50K       0.876
# 5               Black   >50K       0.124
# 6               Other  <=50K       0.908
# 7               Other   >50K       0.092
# 8               White  <=50K       0.744
# 9               White   >50K       0.256

# %%
fig = plt.figure(figsize=(12,8),dpi=98)
color=["#ffa3b1","#77d2fc"]
ax = fig.add_subplot(231)
cts = df.groupby("race").salary.value_counts()["Amer-Indian-Eskimo"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Amer-Indian-Eskimo");

ax = fig.add_subplot(232)
cts = df.groupby("race").salary.value_counts()["Asian-Pac-Islander"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Asian-Pac-Islander");

ax = fig.add_subplot(233)
cts = df.groupby("race").salary.value_counts().Black
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Black");

ax = fig.add_subplot(234)
cts = df.groupby("race").salary.value_counts().Other 
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Other");

ax = fig.add_subplot(235)
cts = df.groupby("race").salary.value_counts().White
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("White");

# %%
# Check the count of person in each races by "salary" levels and visualize it with countplot
df.groupby("salary")["race"].value_counts(dropna=False)
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
ax = sns.countplot(x="salary", data=df, hue="race");
ax.tick_params(rotation=45, axis="x")

# %%
# Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot
df.groupby("salary")["race"].value_counts(dropna=False, normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
df_frame = df.groupby("salary")["race"].value_counts(dropna=False, normalize=True).to_frame(name="percentage").reset_index()
df_frame
# Out:
#   salary                race  percentage
# 0  <=50K               White       0.837
# 1  <=50K               Black       0.111
# 2  <=50K  Asian-Pac-Islander       0.031
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 4  <=50K               Other       0.010
# 5   >50K               White       0.908
# 6   >50K               Black       0.049
# 7   >50K  Asian-Pac-Islander       0.035
# 8   >50K  Amer-Indian-Eskimo       0.005
# 9   >50K               Other       0.003

# %%
sns.countplot(x="salary", hue="race", data=df);
ax.tick_params(rotation=45, axis="x")

# %% [markdown]
# # 6-gender

# %%
# Check the count of person in each gender and visualize it with countplot
df.sex.value_counts(dropna=False)
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
sns.countplot(x="sex", data=df);

# %%
# Check the count of person in each "salary" levels by gender and visualize it with countplot
df.groupby("sex")["salary"].value_counts(dropna=False)
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
sns.countplot(x="sex", hue="salary", data=df);

# %%
# Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot
df.groupby("sex")["salary"].value_counts(dropna=False, normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
fig = plt.figure(figsize=(15,8),dpi=98)
ax = fig.add_subplot(121)
cts = df.groupby("sex").salary.value_counts()["Female"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%")
ax.set_title("Female");

ax = fig.add_subplot(122)
cts = df.groupby("sex").salary.value_counts()["Male"]
ax.pie(cts,labels=cts.index,
      autopct="%.1f%%")
ax.set_title("Male");

# %%
# Check the count of person in each gender by "salary" levels and visualize it with countplot
df.groupby("salary")["sex"].value_counts(dropna=False)
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
sns.countplot(x="salary", hue="sex", data=df);

# %%
# Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot
df.groupby("salary")["sex"].value_counts(dropna=False, normalize=True)
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
fig = plt.figure(figsize=(15,8),dpi=98)
ax = fig.add_subplot(121)
cts = df.groupby("salary").sex.value_counts()["<=50K"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%")
ax.set_title("<=50K");

ax = fig.add_subplot(122)
cts = df.groupby("salary").sex.value_counts()[">50K"]
ax.pie(cts,labels=cts.index,
      autopct="%.1f%%")
ax.set_title(">50K");

# %% [markdown]
# # 7-native_country

# %%
# Check the count of person in each categories and visualize it with countplot
df.native_country.value_counts(dropna=False)
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
ax = sns.countplot(x="native_country", data=df);
ax.tick_params(axis="x", rotation=90)

# %%
# Replace the value "?" to the value "Unknown"
df.native_country.replace(to_replace="?", value="Unknown", inplace=True)
df.native_country.value_counts(dropna=False)
# Out:
# United-States                 29153
# Mexico                          639
# Unknown                         582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# Decrease the number of categories in "native_country" feature as US, and Others 
# and create a new feature with this new categorical data
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"
df["native_country_summary"] = df[native_country].apply(mapping_native_country)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ELITEB~1\AppData\Local\Temp/ipykernel_19004/224668162.py in <module>
#       1 # By using "mapping_native_country" def function above, create a new column named "native_country_summary"
# ----> 2 df["native_country_summary"] = df[native_country].apply(mapping_native_country)
#       3 df.head()
#
# NameError: name 'native_country' is not defined

# %%
df.native_country_summary.value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
df.native_country_summary
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country, Length: 32537, dtype: object

# %%
# Visualize the count of person in each new categories (US, Others)
# ax = sns.countplot(x="native_country_summary", data=df)
ax=sns.countplot(x=df.native_country_summary, data=df);

# %%
# Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot
df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ELITEB~1\AppData\Local\Temp/ipykernel_19004/749334182.py in <module>
#       1 # Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot
# ----> 2 df.groupby("native_country_summary")["salary"].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ...

# %%
# pie plot for each salary level by marital_status_summary 

fig, ax=plt.subplots(figsize=(15,7), nrows=1, ncols=2)
color=["#ffa3b1","#77d2fc"]
ax[0].pie(x=df_sal_perc["percentage"]["<=50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
ax[0].set_title("<=50K")
ax[0].set_ylabel("percentage")

ax[1].pie(x=df_sal_perc["percentage"][">50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
ax[1].set_title(">50K")
ax[1].set_ylabel("percentage");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ELITEB~1\AppData\Local\Temp/ipykernel_19004/616272456.py in <module>
#       3 fig, ax=plt.subplots(figsize=(15,7), nrows=1, ncols=2)
#       4 color=["#ffa3b1","#77d2fc"]
# ----> 5 ax[0].pie(x=df_sal_perc["percentage"]["<=50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
#       6 ax[0].set_title("<=50K")
#       7 ax[0].set_ylabel("percentage")
#
# NameError: name 'df_sal_perc' is not defined

# %%
sns.histplot(x="fnlwgt", data=df, kde=True)

# %%
sns.histplot(x="education-num", data=df, kde=True)

# %%
sns.histplot(x="capital-gain", data=df, kde=True)

# %%
sns.histplot(x="capital-loss", data=df, kde=True)

# %%
sns.histplot(x="hours-per-week", data=df, kde=True)

# %%
sns.boxplot(x=df.age, y=df.salary)

# %%
sns.boxplot(x=df.fnlwgt, y=df.salary)

# %%
sns.boxplot(x="education-num", y=df.salary, data=df)

# %%
sns.boxplot(x="capital-gain", y="salary", data=df)

# %%
sns.boxplot(x="capital-loss", y="salary", data=df)

# %%
sns.boxplot(x="hours-per-week", y="salary", data=df)

# %%
df.groupby("salary").describe().T
# mean value of age is different between salaries

# %%
df.describe(include=np.object)

# %%
sns.countplot(x="workclass", data=df)

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="workclass", data=df)
plt.xticks(size=9)
plt.xlabel("workclass", size=12)
plt.yticks(size=12)
plt.ylabel("count", size=12)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="education", data=df)
ax.set_xticklabels(df.education.value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="marital-status", data=df)
ax.set_xticklabels(df["marital-status"].value_counts().index, rotation=45)
total = float(len(df))

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="occupation", data=df)
ax.set_xticklabels(df["occupation"].value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="relationship", data=df)
ax.set_xticklabels(df["relationship"].value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="race", data=df)
ax.set_xticklabels(df["race"].value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="sex", data=df)
ax.set_xticklabels(df["sex"].value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="native-country", data=df)
ax.set_xticklabels(df["native-country"].value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="salary", data=df)
ax.set_xticklabels(df["salary"].value_counts().index, rotation=45)

total = float(len(df))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()-0.4
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
fig.show()

# %%
df.education.value_counts()

# %%
df_copy =df.copy()

# %%
df_copy["education"] = df_copy["education"].replace([("9th", "10th", "11th", "12th"), "1st-4th", ("5th-6th", "7th-8th")], ["Highschool", "Elementary-School", "Secondary-School"], regex=True)
df_copy.education.value_counts()

# %%
df_copy["education"] = df_copy["education"].replace(["5th-6th", "7th-8th"], "Secondary-School", regex=True)
df_copy.education.value_counts()

# %%
df["marital-status"].value_counts()
# we can join divorced, widowed and separated

# %%
df_copy["marital-status"] = df_copy["marital-status"].replace(["Separated", "Widowed"], "Divorced")
df_copy["marital-status"].value_counts()

# %%
df_copy.head()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
df.groupby(["salary", "sex"])["age"].mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
ax = df.groupby(["salary", "sex"])["age"].mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
len(df[df["salary"] == ">50K"])/len(df)*100
# Out:
# 24.092571533945968

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
len(df_copy[(df_copy["workclass"] == "Private") & (df_copy["salary"] == ">50K")])/len(df_copy)*100

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df_copy[(df_copy["race"]=="Asian-Pac-Islander") & (df_copy["salary"] == ">50K")].groupby("education")

# %%
(df_copy["race"]=="Asian-Pac-Islander") & (df_copy["salary"] == ">50K")

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
sns.catplot(data=df,
           x="education_summary",
           y="hours_per_week",
           kind="bar",
           col="marital_status_summary",
           row="native_country_summary",
           hue="sex");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'native_country_summary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
